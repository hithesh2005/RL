# %% [markdown]
# <a href="https://colab.research.google.com/github/hithesh2005/RL/blob/main/RL_LAB5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
env = gym.make("MountainCar-v0")
print("Environment created")
# Out:
# Environment created

# %%
state, info = env.reset()
print("Car position:", state[0])
print("Car velocity:", state[1])
# Out:
# Car position: -0.55659634
# Car velocity: 0.0

# %%
action = env.action_space
print(action)
# Out:
# Discrete(3)

# %%
action = env.action_space.sample()
if action == 0:
    print("Accelerate left direction")
if action == 1:
    print("No Accelerate")
if action == 2:
    print("Accelerate right direction")
next_state, reward, terminated, truncated, info = env.step(action)
print("Current state:", state)
print("Next state:", next_state)
print("Reward:", reward)
print("Terminated:", terminated)
print("Truncated:", truncated)
# Out:
# Accelerate right direction
# Current state: [-0.55659634  0.        ]
# Next state: [-0.5553493   0.00124708]
# Reward: -1.0
# Terminated: False
# Truncated: False

# %%
current_state, info = env.reset()
print("-" * 40)
print("Current State Information: Reset Environment")
print("-" * 40)
print(f"Car Position: {current_state[0]}")
print(f"Car Velocity: {current_state[1]}")
print("-" * 40)
episodes = 20
total_reward = 0
for episode in range(episodes):
    action = env.action_space.sample()
    if action == 0:
        print("Accelerate left direction")
    if action == 1:
        print("No Accelerate")
    if action == 2:
        print("Accelerate right direction")
    next_state, reward, terminated, truncated, info = env.step(action)
    print(
        f"episode={episode} | next_state={next_state} | "
        f"current_state={current_state} | reward={reward} | "
        f"terminated={terminated}"
    )

    total_reward += reward

    if terminated or truncated:
        current_state, info = env.reset()
    else:
        current_state = next_state

print(f"Total reward={total_reward}")
print(f"Average reward={total_reward / (episodes + 1)}")
# Out:
# ----------------------------------------
# Current State Information: Reset Environment
# ----------------------------------------
# Car Position: -0.47072267532348633
# Car Velocity: 0.0
# ----------------------------------------
# Accelerate left direction
# episode=0 | next_state=[-0.47211757 -0.00139491] | current_state=[-0.47072268  0.        ] | reward=-1.0 | terminated=False
# No Accelerate
# episode=1 | next_state=[-0.47389707 -0.00177949] | current_state=[-0.47211757 -0.00139491] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=2 | next_state=[-0.47504795 -0.00115087] | current_state=[-0.47389707 -0.00177949] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=3 | next_state=[-0.47756165 -0.00251371] | current_state=[-0.47504795 -0.00115087] | reward=-1.0 | terminated=False
# No Accelerate
# episode=4 | next_state=[-0.48041955 -0.0028579 ] | current_state=[-0.47756165 -0.00251371] | reward=-1.0 | terminated=False
# No Accelerate
# episode=5 | next_state=[-0.48360038 -0.00318083] | current_state=[-0.48041955 -0.0028579 ] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=6 | next_state=[-0.4860805 -0.0024801] | current_state=[-0.48360038 -0.00318083] | reward=-1.0 | terminated=False
# No Accelerate
# episode=7 | next_state=[-0.48884138 -0.0027609 ] | current_state=[-0.4860805 -0.0024801] | reward=-1.0 | terminated=False
# No Accelerate
# episode=8 | next_state=[-0.49186248 -0.00302111] | current_state=[-0.48884138 -0.0027609 ] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=9 | next_state=[-0.49612126 -0.00425877] | current_state=[-0.49186248 -0.00302111] | reward=-1.0 | terminated=False
# No Accelerate
# episode=10 | next_state=[-0.50058585 -0.00446462] | current_state=[-0.49612126 -0.00425877] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=11 | next_state=[-0.50622296 -0.00563708] | current_state=[-0.50058585 -0.00446462] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=12 | next_state=[-0.51099026 -0.00476734] | current_state=[-0.50622296 -0.00563708] | reward=-1.0 | terminated=False
# No Accelerate
# episode=13 | next_state=[-0.51585215 -0.00486188] | current_state=[-0.51099026 -0.00476734] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=14 | next_state=[-0.5197721  -0.00391997] | current_state=[-0.51585215 -0.00486188] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=15 | next_state=[-0.5227208  -0.00294867] | current_state=[-0.5197721  -0.00391997] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=16 | next_state=[-0.5246761  -0.00195525] | current_state=[-0.5227208  -0.00294867] | reward=-1.0 | terminated=False
# Accelerate left direction
# episode=17 | next_state=[-0.52762324 -0.00294718] | current_state=[-0.5246761  -0.00195525] | reward=-1.0 | terminated=False
# No Accelerate
# episode=18 | next_state=[-0.5305402  -0.00291699] | current_state=[-0.52762324 -0.00294718] | reward=-1.0 | terminated=False
# Accelerate right direction
# episode=19 | next_state=[-0.53240514 -0.00186494] | current_state=[-0.5305402  -0.00291699] | reward=-1.0 | terminated=False
# Total reward=-20.0
# Average reward=-0.9523809523809523
